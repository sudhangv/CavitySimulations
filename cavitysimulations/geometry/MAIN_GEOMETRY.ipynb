# %%
import meep as mp
import numpy as np
import warnings
import os
import h5py

from lattice import OneDLattice
#from waveguide import *
from utilities import *
from sweep_util import *



def get_perturb_param(to_perturb, w,  a,   hy,  hx , h,
                      target_f_Thz, f_perturb_lower_Thz, f_perturb_upper_Thz, tol_Thz = 1,
                      substrate = False, mode = "yO"):
    
    '''
    Here upper_param and lower_param correspond to the perturbed parameters that result in resonant 
    frequencies of f_perturb_upper_Thz and f_perturb_lower_Thz respectively 
    '''
    del_a, del_hy, del_hx = 0.004, 0.004, 0.004  # increment values for each of the parameters
    
    step_w, step_a, step_hy, step_hx = 0.002, 0.002, 0.002, 0.002
    lower_param = -1             # flags to indicate whether a suitable parameter has been found
    upper_param = -1             # flags to indicate whether a suitable parameter has been found
    
    #  index_w, index_a, index_hy, index_hx = get_index(w = w, a = a, hy = hy, hx = hx)
    
    if to_perturb == 'hx':
        
        run = True
        i = 0
        
        while run:
            i = i + 1
            #----------------- Checking by increasing the parameter to be inspected -----------------------#
            
            freq_to_check_Thz = get_freq_Thz(w = w, a = a, hy = hy, hx = hx + i*del_hx, h = h ,
                                             substrate = substrate, mode = mode)[0]
                                             
            if freq_to_check_Thz < (f_perturb_upper_Thz + tol_Thz) and freq_to_check_Thz > (f_perturb_upper_Thz - tol_Thz):
                
                upper_param = hx + (i * del_hx)
                # if the resonant frequency for the new parameter lies within a tolerance from the peturbed resonant freqeuncy
                # we have found the desired perturbed parameter
                                                            
            if freq_to_check_Thz < (f_perturb_lower_Thz + tol_Thz) and freq_to_check_Thz > (f_perturb_lower_Thz - tol_Thz):
                
                lower_param = hx + (i * del_hx)
            
            #----------------- Checking by decreasing the parameter to be inspected -----------------------#
 
            freq_to_check_Thz = get_freq_Thz(w = w, a = a, hy = hy, hx = hx - i*del_hx, h =h,
                                             substrate = substrate, mode = mode)[0]
                                                    
            if freq_to_check_Thz < (f_perturb_upper_Thz + tol_Thz) and freq_to_check_Thz > (f_perturb_upper_Thz - tol_Thz):
                upper_param = hx + (-i * del_hx)
                
            
            if freq_to_check_Thz < (f_perturb_lower_Thz + tol_Thz) and freq_to_check_Thz > (f_perturb_lower_Thz - tol_Thz):
                lower_param = hx + (-i * del_hx)
                
                
            if upper_param != -1 and lower_param != -1:
                run = False
                
    if to_perturb == 'hy':
        
        run = True
        i = 0
        
        while run:
            i = i + 1
            #----------------- Checking by increasing the parameter to be inspected -----------------------#

            freq_to_check_Thz = get_freq_Thz(w =w , a = a, hy = hy + i*del_hy, hx = hx, h = h,
                                            substrate = substrate, mode = mode)
            
            if freq_to_check_Thz < (f_perturb_upper_Thz + tol_Thz) and freq_to_check_Thz > (f_perturb_upper_Thz - tol_Thz):
                upper_param = hy + (i * del_hy)
            
            if freq_to_check_Thz < (f_perturb_lower_Thz + tol_Thz) and freq_to_check_Thz > (f_perturb_lower_Thz - tol_Thz):
                lower_param = hy + (i * del_hy)
            
            #----------------- Checking by decreasing the parameter to be inspected -----------------------#
            
            freq_to_check_Thz = get_freq_Thz(w =w , a = a, hy = hy - i*del_hy, hx = hx, h = h,
                                            substrate = substrate, mode = mode)
            
            if freq_to_check_Thz < (f_perturb_upper_Thz + tol_Thz) and freq_to_check_Thz > (f_perturb_upper_Thz - tol_Thz):
                upper_param = hy + (-i * del_hy)
            
            if freq_to_check_Thz < (f_perturb_lower_Thz + tol_Thz) and freq_to_check_Thz > (f_perturb_lower_Thz - tol_Thz):
                lower_param = hy + (-i * del_hy)
            
            if upper_param != -1 and lower_param != -1:
                run = False
                
        if to_perturb == 'a':
        
            run = True
            i = 0

            while run:
                
                i = i + 1
                
                #----------------- Checking by increasing the parameter to be inspected -----------------------#
                
             
                freq_to_check_Thz = get_freq_Thz(w = w, a = a + i* del_a, hy = hy , hx = hx, h= h,
                                                substrate = substrate, mode =mode)
                
                if freq_to_check_Thz < (f_perturb_upper_Thz + tol_Thz) and freq_to_check_Thz > (f_perturb_upper_Thz - tol_Thz):
                    upper_param = hy + (i * del_hy)

                if freq_to_check_Thz < (f_perturb_lower_Thz + tol_Thz) and freq_to_check_Thz > (f_perturb_lower_Thz - tol_Thz):
                    lower_param = hy + (i * del_hy)

                #----------------- Checking by decreasing the parameter to be inspected -----------------------#
                
              
                freq_to_check_Thz = get_freq_Thz(w = w, a = a - i* del_a, hy = hy , hx = hx, h =h,
                                                substrate = substrate, mode = mode)
                
                if freq_to_check_Thz < (f_perturb_upper_Thz + tol_Thz) and freq_to_check_Thz > (f_perturb_upper_Thz - tol_Thz):
                    upper_param = a + (-i * del_a)

                if freq_to_check_Thz < (f_perturb_lower_Thz + tol_Thz) and freq_to_check_Thz > (f_perturb_lower_Thz - tol_Thz):
                    lower_param = a + (-i * del_a)

                if upper_param != -1 and lower_param != -1:
                    run = False
            
    return lower_param, upper_param

def get_mirror_param(to_perturb, w,  a_mirror,   hy,  hx , h, substrate, 
                     target_f_Thz, f_perturb_lower_Thz, f_perturb_upper_Thz, 
                     mode, step_size, n_step, lower_param, upper_param ):
    '''
    This function takes the new central segment parameters (hx, hy, a_mirror ,w ) and 
    the new resonant frequencies (f_perturb_lower_Thz,f_perturb_upper_Thz) and returns
    the parameters for the mirror segment that maximize the mirror strength
    
    steps: (a_mirror +- steps * del_a) specify the range within which the new maxima for gamma will be searched
    '''
    
    lower_param = lower_param
    upper_param = upper_param
        
    index_w, index_a_mirror, index_hy, index_hx = get_index(w = w, a = a_mirror, hy = hy, hx = hx)
    
    step_size = step_size
    n_step = n_step
    
    if to_perturb == 'hx':
        hx_lower = lower_param
        hy_lower = hy
        hx_upper = upper_param
        hy_upper = hy
    
    if to_perturb == 'hy':
        hy_lower = lower_param
        hx_lower = hx
        hy_upper = upper_param
        hx_upper = hx   
    
    if to_perturb == 'a':
        hy_lower = hy
        hy_upper = hy
        hx_lower = hx
        hx_upper = hx
        
    freq_mirror_lower = get_freq_Thz(w = w, a = a_mirror, hy =  hy_lower, hx = hx_lower, h = h, substrate = substrate,  mode = mode)  
    freq_mirror_upper = get_freq_Thz(w = w, a = a_mirror, hy =  hy_upper, hx = hx_upper, h = h, substrate = substrate,  mode = mode)  
         
    gamma_mirror_upper = get_gamma_from_Thz(band_edge_f = freq_mirror_upper, check_freq = f_perturb_upper_Thz)
    gamma_mirror_lower = get_gamma_from_Thz(band_edge_f = freq_mirror_lower, check_freq = f_perturb_lower_Thz)

    # freq_mirror : Previous mirror strength of the mirror segment
    # gamma_mirror_upper(lower) denote gamma for the mirror segment at the upper(lower) ends of the resonant 
    # frequency perturbation

    gamma_max_upper = gamma_mirror_upper # upper denotes that the quantity is relevant for the increased resonant frequency           
    gamma_max_lower = gamma_mirror_lower # lower denotes that the quantity is relevant for the decreased resonant frequency
    print("gamma_max_lower :" + str(gamma_max_lower) )
    print("gamma_max_upper :" + str(gamma_max_upper) )
    index_lower = 0
    index_upper = 0
    
    for i in range( n_step + 1):

        # The plus(minus) here denote that the quantity refers to increasing(decreasing) a_mirror 
        # upper and lower retain their meaning from the previous comments

        freq_plus_upper_Thz = get_freq_Thz( w = w, a = a_mirror + i* step_size, hy = hy_upper, hx = hx_upper, 
                                           h =h, substrate = substrate,  mode = mode)

        freq_minus_upper_Thz = get_freq_Thz( w = w, a = a_mirror - i* step_size, hy = hy_upper, hx = hx_upper, 
                                           h = h, substrate = substrate,  mode = mode)

        freq_plus_lower_Thz = get_freq_Thz( w = w, a = a_mirror + i* step_size, hy = hy_lower, hx = hx_lower, 
                                           h =h, substrate = substrate,  mode = mode)

        freq_minus_lower_Thz = get_freq_Thz( w = w, a = a_mirror - i* step_size, hy = hy_lower, hx = hx_lower, 
                                           h = h, substrate = substrate,  mode = mode)

        gamma_plus_upper = get_gamma_from_Thz(band_edge_f = freq_plus_upper_Thz, check_freq = f_perturb_upper_Thz)
        #print("gamma_plus_upper :" + str(gamma_plus_upper) )
        gamma_minus_upper = get_gamma_from_Thz(band_edge_f = freq_minus_upper_Thz, check_freq = f_perturb_upper_Thz)
        #print("gamma_minus_upper :" + str(gamma_minus_upper) )
        gamma_plus_lower = get_gamma_from_Thz(band_edge_f = freq_plus_lower_Thz, check_freq = f_perturb_lower_Thz)
        #print("gamma_plus_lower :" + str(gamma_plus_lower) )
        gamma_minus_lower = get_gamma_from_Thz(band_edge_f = freq_minus_lower_Thz, check_freq = f_perturb_lower_Thz)
        #print("gamma_minus_lower :" + str(gamma_minus_lower) )


        if gamma_plus_lower > gamma_max_lower:
            gamma_max_lower = gamma_plus_lower
            index_lower = i
            # index relative to the orignal a_mirror
        if gamma_minus_lower > gamma_max_lower:
            gamma_max_lower = gamma_minus_lower
            index_lower = -i 

        if gamma_plus_upper > gamma_max_upper:
            gamma_max_upper = gamma_plus_upper
            index_upper = i

        if gamma_minus_upper > gamma_max_upper:
            
            gamma_max_upper = gamma_minus_upper
            index_upper = -i

    a_mirror_new_lower = a_mirror + index_lower * step_size
    a_mirror_new_upper = a_mirror + index_upper * step_size
    print("FOUNDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD")
    return (a_mirror_new_lower, a_mirror_new_upper)
        
def _a_poly_tapering(geom=None, n_segments=20, material_holes=mp.vacuum):
    
    filename = "bandstructure_data/sweep_data.hdf5"
    
    hf = h5py.File(filename, 'r')
    gamma_data = np.array( hf.get("gamma"))
    freq_data = np.array( hf.get("freq"))
    hf.close()
    
    if geom is None:
         geom = []
            
    material_holes = index_to_material(material_holes)
    
    #--------------- These are the parameters for DESIGNED geometry, which we want to perturb ------------ #
               
    
    hx = 0.225
    hy = 0.4
    a_mirror = 0.414
    a_cen = 0.385
    w = 0.65
    h  = 0.19
    mode = "zEyO"
    
    substrate = True
    
    Lx = 20
    _n_taper = 10
    
    _cavity = OneDLattice(Lx = Lx)
    
    # ------------------------------ PERTURBATION HERE -------------------------------------------- #
    # Essentially how this works is that at the end of all the repetitive code, you get 4 values:
    # (1) lower_param : the value of the parameter that gives a resonant frequency slightly lower than the earlier one
    # (2) upper_param : the value of the parameter that gives a resonant frequency slightly higher than the earlier one
    # (3) a_mirror_new_lower : the new a_mirror that maximizes gamma for positive delta_freq and new hy/hx 
    # (4) a_mirror_new_upper : the new a_mirror that maximizes gamma for negative delta_freq and new hy/x
    
    to_perturb = "hx"            # one of hx, hy and a
    perturb_range = 0.04         # edges of the wavelength (in um) window will be (target_lambda +- perturb_range) 
    tol_Thz = 1                 # tolerance in Thz to select the perturbed segment parameters
    
    target_wvl = 1.54            # vaccum wavelength ( in um ) of the unperturbed cavity design
    target_f = 1/target_wvl
    target_f_Thz =  convert_freq_to_Thz(target_f)
    
    f_perturb_lower = 1 / (target_wvl + perturb_range )           # target_f - perturbation
    f_perturb_upper = 1 / (target_wvl - perturb_range )           # target_f + perturbation
    
    f_perturb_lower_Thz =  convert_freq_to_Thz(f_perturb_lower)
    f_perturb_upper_Thz =  convert_freq_to_Thz(f_perturb_upper)
    
    lower_param, upper_param = get_perturb_param(to_perturb = to_perturb , 
                                                 w = w,  a = a_cen,   hy = hy,  hx = hx , h =h, 
                                                 target_f_Thz= target_f_Thz, substrate = substrate,
                                                 f_perturb_lower_Thz= f_perturb_lower_Thz, 
                                                 f_perturb_upper_Thz= f_perturb_upper_Thz, tol_Thz = tol_Thz,
                                                 mode = mode)


    step_size = 0.004            # size of each of the n_steps
    n_step = 7                   # number of steps to search for the optimal gamma for the mirror segment
    
    a_mirror_new_lower, a_mirror_new_upper = get_mirror_param(to_perturb = to_perturb,
                                                             w = w,  a_mirror = a_mirror,   
                                                             hy = hy,  hx = hx , h = h,
                                                             target_f_Thz = target_f_Thz, 
                                                             f_perturb_lower_Thz = f_perturb_lower_Thz, 
                                                             f_perturb_upper_Thz = f_perturb_upper_Thz, 
                                                             mode = mode, substrate = substrate,
                                                             step_size = step_size, n_step = n_step,
                                                             lower_param = lower_param, upper_param = upper_param)

    
    # Here upper_param and lower_param correspond to the perturbed parameters that result in resonant 
    # frequencies of f_perturb_upper_Thz and f_perturb_lower_Thz respectively 
    
    # a_mirror_new_lower,a_mirror_new_upper refer to the new values of a_mirror that maximise gamma_mirror for
    # the the two ends of the perturbation window
    
    
    
    #----------------------------------------------------------------------------------------------------#
    
    _cavity.polynomial_elliptical_hole_taper(_n_taper, hx, hy, w, a_cen, a_mirror )
    _cavity.apply_poly_spacing()
    
    print("--------------------------------------------------------------------------------------------------------")
    print(" Poly Tapering : hx = {}, hy = {}, w = {}, h= {}, a_cen  = {},  a_mirror = {}, n_taper = {}, Lx = {}".format(hx, hy,w, h, a_cen,a_mirror,_n_taper,Lx))
    print("--------------------------------------------------------------------------------------------------------")

    # cavity holes
    for x, y, z, hx, hy in _cavity.coordinates:
        # holes are completely filled with tuning material:
        geom.append(mp.Ellipsoid(material=material_holes,
                                         center=mp.Vector3(x, y, z),
                                         size=mp.Vector3(hx, hy, mp.inf)))

        geom.append(mp.Ellipsoid(material=material_holes,
                                         center=mp.Vector3(-x, y, z),
                                         size=mp.Vector3(hx, hy, mp.inf)))

    length = 2 * max(_cavity.coordinates[:, 0])

    return geom, length

def _a_pow_tapering(geom=None, n_segments=20, material_holes=mp.vacuum):
  
    if geom is None:
        geom = []
        
    material_holes = index_to_material(material_holes)
    hx = 0.143
    hy = 0.315                                                                                                              
    w = 0.65
    a_cen = 0.36
    a_mirror = 0.414
    Lx = 20
    h = 0.19
    
    substrate = False
    _cavity = OneDLattice(Lx = Lx)
    _n_taper = 10
    _cavity.pow_degree_a_taper(_n_taper, 
                               hx = hx, 
                               hy = hy, 
                               w = w, 
                               a_center = a_cen,
                               a_mirror = a_mirror,
                               pow = 2)
    
    _cavity.apply_pow_spacing()
    
    print("--------------------------------------------------------------------------------------------------------")
    print(" Pow Tapering : hx = {}, hy = {}, w = {}, h = {}, a_cen  = {},  a_mirror = {}, n_taper = {}, Lx = {}".format(hx, hy, w, h, a_cen, a_mirror, _n_taper, Lx))    
    print("--------------------------------------------------------------------------------------------------------") 

    # cavity holes
    for x, y, z, hx, hy in _cavity.coordinates:
        # holes are completely filled with tuning material:
        geom.append(mp.Ellipsoid(material=material_holes,
                                         center=mp.Vector3(x, y, z),
                                         size=mp.Vector3(hx, hy, mp.inf)))

        geom.append(mp.Ellipsoid(material=material_holes,
                                         center=mp.Vector3(-x, y, z),
                                         size=mp.Vector3(hx, hy, mp.inf)))

    length = 2 * max(_cavity.coordinates[:, 0])

    return geom, length

def _a_normal_tapering(geom=None, n_segments=20, material_holes=mp.vacuum):
     
    if geom is None:
        geom = []
    material_holes = index_to_material(material_holes)

    _cavity = OneDLattice(Lx = n_segments)
    _cavity.normal_spacing(a = 0.303, hx = 0.143, hy = 0.315)
    
    for x, y, z, hx, hy in _cavity.coordinates:
        # holes are completely filled with tuning material:
        geom.append(mp.Ellipsoid(material=material_holes,
                                         center=mp.Vector3(x, y, z),
                                         size=mp.Vector3(hx, hy, mp.inf)))
        geom.append(mp.Ellipsoid(material=material_holes,
                                         center=mp.Vector3(-x, y, z),
                                         size=mp.Vector3(hx, hy, mp.inf)))
    length = 10                             
    return geom, length

def a_pow_tapered_cavity(geom = None, n_segments=20, waveguide_parameters= None, substrate_parameters=None):
    """
    Returns the geometry objects for a the air holes of 1D phc cavity with tapered lattice constants.
    """
    if geom is None:
        geom = []

    if waveguide_parameters is None:
        waveguide_parameters = {}

    if substrate_parameters is None:
        substrate_parameters = {}

    geom = add_waveguide_1d(geom=geom)

    geom, _ = _a_pow_tapering(geom=geom, n_segments=n_segments)

    # geom = add_substrate(geom=geom, **substrate_parameters)

    return geom

def a_normal_cavity(geom = None, n_segments=20, waveguide_parameters= None, substrate_parameters=None):    
    
    if geom is None:
        geom = []

    if waveguide_parameters is None:
        waveguide_parameters = {}

    if substrate_parameters is None:
        substrate_parameters = {}

    geom = add_waveguide_1d(geom=geom)

    geom, _ = _a_normal_tapering(geom=geom, n_segments=n_segments)

    # geom = add_substrate(geom=geom, **substrate_parameters)                                                           

    return geom
                                                                                        
                                                                                                                                                               
def a_poly_tapered_cavity(geom=None, n_segments=20, waveguide_parameters=None, substrate_parameters=None):
    
    if geom is None:
        geom = []

    if waveguide_parameters is None:
        waveguide_parameters = {}

    if substrate_parameters is None:
        substrate_parameters = {}

    geom = add_waveguide_1d(geom=geom, **waveguide_parameters)

    geom, _ = _a_poly_tapering(geom=geom, n_segments=n_segments)

    geom = add_substrate(geom=geom, **substrate_parameters)

    return geom

# %%
_a_poly_tapering()
# Out:
#  lower_param, upper_param: (0.245, 0.285)
# h = 0.19
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.57005,0.458937)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.591787,0.966184,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11473)
#           size (1e+20,1e+20,1.77053)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.13965153694152832
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 23 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.248277, 0.335328
# elapsed time for k point: 3.072357177734375
# total elapsed time for run: 3.2121548652648926
# done
# freq mirror lower:[179.91051548 242.99116418]
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.57005,0.458937)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.688406,0.966184,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11473)
#           size (1e+20,1e+20,1.77053)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.21245169639587402
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 12 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.256706, 0.353524
# elapsed time for k point: 1.7248337268829346
# total elapsed time for run: 1.9374072551727295
# done
# freq mirror upper:[186.01847912 256.17649745]
# gamma_max_lower :0.10879359823689602
# gamma_max_upper :0.12675664267278197
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.57005,0.458937)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.688406,0.966184,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11473)
#           size (1e+20,1e+20,1.77053)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.19856929779052734
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 29 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.256688, 0.353794
# elapsed time for k point: 4.023558855056763
# total elapsed time for run: 4.222264289855957
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.57005,0.458937)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.688406,0.966184,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11473)
#           size (1e+20,1e+20,1.77053)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.1996622085571289
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 14 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.256706, 0.353672
# elapsed time for k point: 1.929020881652832
# total elapsed time for run: 2.128870964050293
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.57005,0.458937)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.591787,0.966184,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11473)
#           size (1e+20,1e+20,1.77053)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.20145130157470703
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 17 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.248271, 0.33547
# elapsed time for k point: 2.339604139328003
# total elapsed time for run: 2.541246175765991
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.57005,0.458937)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.591787,0.966184,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11473)
#           size (1e+20,1e+20,1.77053)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.2052469253540039
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 27 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.248273, 0.33545
# elapsed time for k point: 3.6872920989990234
# total elapsed time for run: 3.8926751613616943
# done
# gamma_plus_upper :0.126983138549037
# gamma_minus_upper :0.12684551179736622
# gamma_plus_lower :0.10889572229350734
# gamma_minus_lower :0.10887794989467867
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.55502,0.454545)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.681818,0.956938,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11364)
#           size (1e+20,1e+20,1.77273)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.20514249801635742
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 28 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.256846, 0.35418
# elapsed time for k point: 3.8966736793518066
# total elapsed time for run: 4.101987838745117
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.58537,0.463415)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.695122,0.97561,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11585)
#           size (1e+20,1e+20,1.76829)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.21747946739196777
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 13 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.256594, 0.353736
# elapsed time for k point: 1.9502277374267578
# total elapsed time for run: 2.167841672897339
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.55502,0.454545)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.586124,0.956938,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11364)
#           size (1e+20,1e+20,1.77273)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.2420368194580078
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 15 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.248742, 0.335383
# elapsed time for k point: 2.2273409366607666
# total elapsed time for run: 2.469510793685913
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.58537,0.463415)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.597561,0.97561,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11585)
#           size (1e+20,1e+20,1.76829)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.21668767929077148
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 12 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.247809, 0.335627
# elapsed time for k point: 1.8056859970092773
# total elapsed time for run: 2.0224997997283936
# done
# gamma_plus_upper :0.13286682086031606
# gamma_minus_upper :0.12021933437184165
# gamma_plus_lower :0.11459396042033622
# gamma_minus_lower :0.10224414216968075
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.54028,0.450237)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.675355,0.947867,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11256)
#           size (1e+20,1e+20,1.77488)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.2191779613494873
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 23 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.257206, 0.354345
# elapsed time for k point: 3.3642499446868896
# total elapsed time for run: 3.583888053894043
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.60099,0.46798)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.70197,0.985222,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.117)
#           size (1e+20,1e+20,1.76601)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.22617363929748535
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 13 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.255711, 0.352495
# elapsed time for k point: 1.9516093730926514
# total elapsed time for run: 2.177907705307007
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.54028,0.450237)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.580569,0.947867,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11256)
#           size (1e+20,1e+20,1.77488)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.22737336158752441
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 18 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.249417, 0.335403
# elapsed time for k point: 2.697390556335449
# total elapsed time for run: 2.925368070602417
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.60099,0.46798)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.603448,0.985222,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.117)
#           size (1e+20,1e+20,1.76601)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.22173523902893066
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 25 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.246695, 0.334709
# elapsed time for k point: 3.6886532306671143
# total elapsed time for run: 3.9105336666107178
# done
# gamma_plus_upper :0.1372614320994412
# gamma_minus_upper :0.11503811821743791
# gamma_plus_lower :0.11882293728701777
# gamma_minus_lower :0.09719047396245185
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.52582,0.446009)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.669014,0.938967,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.1115)
#           size (1e+20,1e+20,1.777)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.23750972747802734
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 19 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.257778, 0.355609
# elapsed time for k point: 2.8497190475463867
# total elapsed time for run: 3.087367534637451
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.61692,0.472637)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.708955,0.995025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11816)
#           size (1e+20,1e+20,1.76368)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.23625540733337402
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 19 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.255633, 0.352362
# elapsed time for k point: 2.856748580932617
# total elapsed time for run: 3.0931472778320312
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.52582,0.446009)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.575117,0.938967,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.1115)
#           size (1e+20,1e+20,1.777)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.22705841064453125
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 37 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.250258, 0.335857
# elapsed time for k point: 5.534968376159668
# total elapsed time for run: 5.762209892272949
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.61692,0.472637)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.609453,0.995025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11816)
#           size (1e+20,1e+20,1.76368)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.2273390293121338
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 18 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.246194, 0.334685
# elapsed time for k point: 2.7526938915252686
# total elapsed time for run: 2.9802298545837402
# done
# gamma_plus_upper :0.14129057778198925
# gamma_minus_upper :0.10625284420055908
# gamma_plus_lower :0.12220033777504655
# gamma_minus_lower :0.08851926389175842
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.51163,0.44186)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.662791,0.930233,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11047)
#           size (1e+20,1e+20,1.77907)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.22775697708129883
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 23 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.25813, 0.355666
# elapsed time for k point: 3.4798991680145264
# total elapsed time for run: 3.707786798477173
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.63317,0.477387)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.71608,1.00503,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11935)
#           size (1e+20,1e+20,1.76131)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.2511444091796875
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 14 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.255526, 0.351858
# elapsed time for k point: 2.2391510009765625
# total elapsed time for run: 2.490442991256714
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.51163,0.44186)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.569767,0.930233,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11047)
#           size (1e+20,1e+20,1.77907)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.24149131774902344
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 14 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.250935, 0.335897
# elapsed time for k point: 2.1975958347320557
# total elapsed time for run: 2.4394030570983887
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.63317,0.477387)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.615578,1.00503,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.11935)
#           size (1e+20,1e+20,1.76131)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.23078560829162598
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 13 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.245643, 0.334525
# elapsed time for k point: 2.0523767471313477
# total elapsed time for run: 2.28330135345459
# done
# gamma_plus_upper :0.1445873137792267
# gamma_minus_upper :0.09591921267832648
# gamma_plus_lower :0.1253360556565721
# gamma_minus_lower :0.07837466208791768
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.4977,0.437788)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.656682,0.921659,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.10945)
#           size (1e+20,1e+20,1.78111)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.23595118522644043
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 16 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.258731, 0.356287
# elapsed time for k point: 2.5352017879486084
# total elapsed time for run: 2.7713067531585693
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.64975,0.482234)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.72335,1.01523,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.12056)
#           size (1e+20,1e+20,1.75888)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.23839926719665527
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 13 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.255307, 0.350343
# elapsed time for k point: 2.081369638442993
# total elapsed time for run: 2.3199894428253174
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.4977,0.437788)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.564516,0.921659,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.10945)
#           size (1e+20,1e+20,1.78111)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.23351287841796875
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 12 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.251766, 0.33614
# elapsed time for k point: 1.9333131313323975
# total elapsed time for run: 2.1670138835906982
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.64975,0.482234)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.621827,1.01523,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.12056)
#           size (1e+20,1e+20,1.75888)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.23503589630126953
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 24 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.245015, 0.333585
# elapsed time for k point: 3.84094500541687
# total elapsed time for run: 4.076187372207642
# done
# gamma_plus_upper :0.14719999452620017
# gamma_minus_upper :0.08388450513253325
# gamma_plus_lower :0.12767068000380438
# gamma_minus_lower :0.06617644999549241
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.48402,0.43379)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.650685,0.913242,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.10845)
#           size (1e+20,1e+20,1.78311)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.23401236534118652
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 14 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.259178, 0.356167
# elapsed time for k point: 2.2721657752990723
# total elapsed time for run: 2.5064399242401123
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.66667,0.487179)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.730769,1.02564,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.12179)
#           size (1e+20,1e+20,1.75641)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.23740339279174805
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 15 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.255378, 0.350152
# elapsed time for k point: 2.384377956390381
# total elapsed time for run: 2.6219310760498047
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.48402,0.43379)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.559361,0.913242,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.10845)
#           size (1e+20,1e+20,1.78311)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.27913355827331543
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 12 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.252421, 0.336199
# elapsed time for k point: 2.0745177268981934
# total elapsed time for run: 2.353790283203125
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.66667,0.487179)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.628205,1.02564,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.12179)
#           size (1e+20,1e+20,1.75641)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.23682355880737305
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 14 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.244646, 0.33376
# elapsed time for k point: 2.2694573402404785
# total elapsed time for run: 2.5068178176879883
# done
# gamma_plus_upper :0.14916015421165207
# gamma_minus_upper :0.06742091817043498
# gamma_plus_lower :0.12993842879053272
# gamma_minus_lower :0.04770072227110052
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.47059,0.429864)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.644796,0.904977,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.10747)
#           size (1e+20,1e+20,1.78507)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.25356531143188477
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 18 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.260396, 0.356844
# elapsed time for k point: 2.9572269916534424
# total elapsed time for run: 3.212475061416626
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.68394,0.492228)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.738342,1.03627,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.12306)
#           size (1e+20,1e+20,1.75389)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.24115443229675293
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 22 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.255543, 0.349503
# elapsed time for k point: 3.659479856491089
# total elapsed time for run: 3.9007818698883057
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.47059,0.429864)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.554299,0.904977,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.10747)
#           size (1e+20,1e+20,1.78507)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.24087166786193848
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 21 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.253747, 0.336482
# elapsed time for k point: 3.4233944416046143
# total elapsed time for run: 3.6644041538238525
# done
#  h = 0.19, SUBSTRATE = True, mode = zEyO
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.68394,0.492228)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.634715,1.03627,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-1.12306)
#           size (1e+20,1e+20,1.75389)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 2 and 27 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.23945069313049316
# solve_kpoint (0.5,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2
# Solving for bands 1 to 2...
# Finished solving for bands 1 to 2 after 13 iterations.
# zevenyoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.244278, 0.333473
# elapsed time for k point: 2.106091260910034
# total elapsed time for run: 2.3456902503967285
# done
# gamma_plus_upper :0.14957265226996191
# gamma_minus_upper :0.042464256465342694
# gamma_plus_lower :0.13014421378207192
# gamma_minus_lower :0.0052887086600735414
# FOUNDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD
# a_mirror_new_lower,a_mirror_new_upper : 0.442,0.442
# --------------------------------------------------------------------------------------------------------
#  Poly Tapering : hx = 0.225, hy = 0.4, w = 0.65, h= 0.19, a_cen  = 0.385,  a_mirror = 0.414, n_taper = 10, Lx = 20
# --------------------------------------------------------------------------------------------------------
# ([<meep.geom.Ellipsoid at 0x7f880b38e310>,
#   <meep.geom.Ellipsoid at 0x7f880bc767d0>,
#   <meep.geom.Ellipsoid at 0x7f880c75b290>,
#   <meep.geom.Ellipsoid at 0x7f880c707610>,
#   <meep.geom.Ellipsoid at 0x7f880c6eff10>,
#   <meep.geom.Ellipsoid at 0x7f880c754d90>,
#   <meep.geom.Ellipsoid at 0x7f880b382310>,
#   <meep.geom.Ellipsoid at 0x7f880b382e50>,
#   <meep.geom.Ellipsoid at 0x7f880b382e10>,
#   <meep.geom.Ellipsoid at 0x7f880c6eb1d0>,
#   <meep.geom.Ellipsoid at 0x7f880b382bd0>,
#   <meep.geom.Ellipsoid at 0x7f880b382f90>,
#   <meep.geom.Ellipsoid at 0x7f880bd96150>,
#   <meep.geom.Ellipsoid at 0x7f880bd962d0>,
#   <meep.geom.Ellipsoid at 0x7f880bd96450>,
#   <meep.geom.Ellipsoid at 0x7f880bd965d0>,
#   <meep.geom.Ellipsoid at 0x7f880bd96750>,
#   <meep.geom.Ellipsoid at 0x7f880bd968d0>,
#   <meep.geom.Ellipsoid at 0x7f880bd96a50>,
#   <meep.geom.Ellipsoid at 0x7f880bd96bd0>,
#   <meep.geom.Ellipsoid at 0x7f880bd96d50>,
#   <meep.geom.Ellipsoid at 0x7f880bd96ed0>,
#   <meep.geom.Ellipsoid at 0x7f880bd9b090>,
#   <meep.geom.Ellipsoid at 0x7f880bd9b210>,
#   <meep.geom.Ellipsoid at 0x7f880bd9b390>,
#   <meep.geom.Ellipsoid at 0x7f880bd9b510>,
#   <meep.geom.Ellipsoid at 0x7f880bd9b690>,
#   <meep.geom.Ellipsoid at 0x7f880bd9b810>,
#   <meep.geom.Ellipsoid at 0x7f880bd9b990>,
#   <meep.geom.Ellipsoid at 0x7f880bd9bb10>,
#   <meep.geom.Ellipsoid at 0x7f880bd9bc90>,
#   <meep.geom.Ellipsoid at 0x7f880bd9be10>,
#   <meep.geom.Ellipsoid at 0x7f880bd9bf90>,
#   <meep.geom.Ellipsoid at 0x7f880bd9e150>,
#   <meep.geom.Ellipsoid at 0x7f880bd9e2d0>,
#   <meep.geom.Ellipsoid at 0x7f880bd9e450>,
#   <meep.geom.Ellipsoid at 0x7f880bd9e5d0>,
#   <meep.geom.Ellipsoid at 0x7f880bd9e750>,
#   <meep.geom.Ellipsoid at 0x7f880bd9e8d0>,
#   <meep.geom.Ellipsoid at 0x7f880bd9ea50>],
#  15.784504876790379)

# %%
filename = "bandstructure_data/sweep_data.hdf5"
    
hf = h5py.File(filename, 'r')
gamma_data = np.array( hf.get("gamma"))
freq_data = np.array( hf.get("freq"))
hf.close()

# %%
freq_data.shape
print(get_index(hx = 0.275, hy = 0.425, a = 0.449, w = 0.65))

# %%
print([freqs for freqs in freq_data[0, 150:199, 13, 9])

# %%
freq_data.shape

# %%
freq_data[0, 138, 13, 9]

# %%
a_min + 135 * (del_a)

# %%
# hx = 0.275
#     hy = 0.425
#     a_mirror = 0.449
#     a_cen = 0.388
#     w = 0.65
#     h  = 0.25
    
#     substrate = False
    
#     Lx = 20
#     _n_taper = 10
#lower_param, upper_param: (0.255, 0.29100000000000004
get_freq_Thz(hx = 0.255, hy = 0.5, a = 0.385, h = 0.19, w = 0.7, substrate = True, mode = "zEyO")

# %%
convert_freq_to_Thz(1/1.58), convert_freq_to_Thz(1/1.50)

# %%
f_perturb
